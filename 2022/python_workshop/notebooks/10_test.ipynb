# %% [markdown]
# # Practical exam

# %%
### Please state your name here:
Ghiba Florina-Maria

# %%
# make sure requirements are up to date
# %pip install --upgrade pip >> results/requirements_log.txt
# %pip install -r ../requirements.txt >> results/requirements_log.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 1.
#
# Given the below snippet, add the necessary code lines in function f2 in order to obtain the expected output:

# %%
def f2(n):
    for i in range(1, n):
        print(f"~~~ {i}")
        print('{cubed}:1')
        print('{squared}:1')
        print(f"@@@ {i}")

        i += 1
        continue
  
   



n = 5
for x in f2(n):
    print(x)
# Out:
# ~~~ 1
# {cubed}:1
# {squared}:1
# @@@ 1
# ~~~ 2
# {cubed}:1
# {squared}:1
# @@@ 2
# ~~~ 3
# {cubed}:1
# {squared}:1
# @@@ 3
# ~~~ 4
# {cubed}:1
# {squared}:1
# @@@ 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Laptop 20\Desktop\ghibs\bootcamp\2022\python_workshop\notebooks\10_test.ipynb Cell 5 in <cell line: 16>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Laptop%2020/Desktop/ghibs/bootcamp/2022/python_workshop/notebooks/10_test.ipynb#ch0000004?line=8'>9</a>         continue
#      <a href='vscode-notebook-cell:/c%3A/Users/Laptop%2020/Desktop/ghibs/bootcamp/2022/python_workshop/notebooks/10_test.ipynb#ch0000004?line=14'>15</a> n = 5
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Laptop%2020/Desktop/ghibs/bootcamp/2022/python_workshop/notebooks/10_test.ipynb#ch0000004?line=15'>16</a> for x in f2(n):
#      <a href='vscode-notebook-cell:/c%3A/Users/Laptop%2020/Desktop/ghibs/bootcamp/2022/python_workshop/notebooks/10_test.ipynb#ch0000004?line=16'>17</a>     print(x)
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# Expected output:
#
# ```
# ~~~ 1
# {'cubed': 1}
# {'squared': 1}
# @@@ 1
# ~~~ 2
# {'cubed': 8}
# {'squared': 4}
# @@@ 2
# ~~~ 3
# {'cubed': 27}
# {'squared': 9}
# @@@ 3
# ~~~ 4
# {'cubed': 64}
# {'squared': 16}
# @@@ 4
# ```

# %% [markdown]
# ### 2.
#
# Under **resources**, there are two input files, [input_file_1.csv](/2022/python_workshop/notebooks/resources/input_file_1.csv) and [input_file_2.csv](/2022/python_workshop/notebooks/resources/input_file_2.csv).
#
# Given the two input files, remove the duplicates.
#
# If rows in all files are combined, there must be NO duplicates. Solution should include 2 functions, one for reading data from files and one for writing data to files. A partial solution without functions is accepted.
#
# Expected output: two separate output files under results/expected, [output_file_1.csv](/2022/python_workshop/notebooks/results/expected/output_file_1.csv) and [output_file_2.csv](/2022/python_workshop/notebooks/results/expected/output_file_2.csv).

# %% [markdown]
# ### 3.
#
# Using the [data.gov.ro](https://data.gov.ro/dataset/acreditarea-unitatilor-sanitare-2021) API, extract the "accredited hospitals 2021" data set (link available below).
#
# Alternatively, if the API is down, use the backup file **hospitals.csv** from the **resources** folder as a source.

# %%
import requests
import pandas as pd

# %%
import json
from urllib import response


url_hospitals = 'https://data.gov.ro/dataset/4197b53e-7c91-4fcc-be07-883076d40ffc/resource/7a343719-d625-4b5c-98b5-895a684d61c4/download/anmcs-acreditare-unitati-sanitare-dec2021.json'
response = requests.get(url_hospitals)
hospitals = response.text
parsed = json.loads(hospitals)
print(json.dumps(parsed, indent=4))

print(hospitals.head())
# Out:
# [
#     {
#         "Nr. Crt.": 1,
#         "Nume": "SPITALUL MUNICIPAL CALAFAT",
#         "Cod A.N.M.C.S.": "A001",
#         "Judet": "Dolj",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "B-dul. T. Vladimirescu, Nr. 24, Calafat, cod 205200, Dolj, Romania",
#         "Adresa email oficiala": "spitalcalafat@gmail.com",
#         "Website": "spitalcalafat.ro",
#         "Autoritatea tutelara": "PRIMARIA MUNICIPIULUI CALAFAT",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria V Decizie de prelungire a procesului de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 2,
#         "Nume": "SPITALUL DE PSIHIATRIE CRONICI SCHITU GRECI",
#         "Cod A.N.M.C.S.": "A002",
#         "Judet": "Olt",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "afectiuni cronice",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "SLATINA STR. A. I. CUZA NR. 14",
#         "Adresa email oficiala": "spitalulschitu@gmail.com",
#         "Website": "www.spitalul-schitu.ro",
#         "Autoritatea tutelara": "CONSILIUL JUDETEAN OLT",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria V Decizie de prelungire a procesului de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 3,
#         "Nume": "SPITALUL CLINIC NICOLAE MALAXA",
#         "Cod A.N.M.C.S.": "A003",
#         "Judet": "Bucuresti",
#         "Clasificare": "III",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "clinic cu sectii universitare",
#         "Adresa completa a sediului principal": "STR. DIMITRIE CANTEMIR, NR.1, PARTER, SECT.4, BUCUREsTI",
#         "Adresa email oficiala": "secretariat@spitalmalaxa.ro",
#         "Website": "www.spitalmalaxa.ro",
#         "Autoritatea tutelara": "ASSMB",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria IV Acreditat cu incredere redusa",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 4,
#         "Nume": "SPITALUL MILITAR DE URGENTA \"REGINA MARIA\" BRA?OV",
#         "Cod A.N.M.C.S.": "A004",
#         "Judet": "Brasov",
#         "Clasificare": "III",
#         "TIP USP (in functie de specificul patologiei tratate)": "urgenta",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Bucuresti, Str. Institutul Medico-Militar, Nr. 3 - 5, Sector 1, Cod postal 010919",
#         "Adresa email oficiala": "smureginamaria@rdsbv.ro",
#         "Website": "www.smubrasov.ro",
#         "Autoritatea tutelara": "DIRECtIA MEDICALa a Ministerului Apararii Nationale",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 5,
#         "Nume": "SPITALUL ORASENESC INEU",
#         "Cod A.N.M.C.S.": "A005",
#         "Judet": "Arad",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Calea Republicii, nr. 5",
#         "Adresa email oficiala": "spitalineu@yahoo.ro",
#         "Website": "http://www.spitalineu.ro",
#         "Autoritatea tutelara": "Primaria Orasului Ineu",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria V Decizie de prelungire a procesului de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 6,
#         "Nume": "SPITALUL ORASENESC BECLEAN",
#         "Cod A.N.M.C.S.": "A006",
#         "Judet": "Bistrita-Nasaud",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Aleea Trandafirilor , nr. 2, Beclean, Bistrita-Nasaud,",
#         "Adresa email oficiala": "administrativ@spitalbeclean.ro",
#         "Website": "www.spitalbeclean.ro",
#         "Autoritatea tutelara": "Consiliul local / Primaria Oras Beclean",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria III Acreditat cu rezerve",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 7,
#         "Nume": "SPITALUL CLINIC DE URGENTA \"PROF.DR.N.OBLU\" IASI",
#         "Cod A.N.M.C.S.": "A007",
#         "Judet": "Iasi",
#         "Clasificare": "II M",
#         "TIP USP (in functie de specificul patologiei tratate)": "urgenta",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "clinic cu sectii universitare",
#         "Adresa completa a sediului principal": "IASI, B-DUL STEFAN CEL MARE SI SFANT NR.69",
#         "Adresa email oficiala": "neuroiasi@neuroiasi.ro",
#         "Website": "www.neuroiasi.ro",
#         "Autoritatea tutelara": "CONSILIUL JUDETEAN IASI",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 8,
#         "Nume": "SPITALUL JUDETEAN DE URGENTA DEVA",
#         "Cod A.N.M.C.S.": "A008",
#         "Judet": "Hunedoara",
#         "Clasificare": "III",
#         "TIP USP (in functie de specificul patologiei tratate)": "urgenta",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Str. 1 Decembrie 1918 Nr.28;",
#         "Adresa email oficiala": "spjudeva1@gmail.com",
#         "Website": "spitaldeva.ro",
#         "Autoritatea tutelara": "Consiliul Judetean Hunedoara",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 9,
#         "Nume": "S.C. COMPLEX BALNEAR SI DE RECUPERARE C.A.A. S.R.L.",
#         "Cod A.N.M.C.S.": "A009",
#         "Judet": "Constanta",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "privat",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Techirghiol, str. Dr. Victor Climescu, nr 40A",
#         "Adresa email oficiala": "administrativ@balnear-corporesano.ro",
#         "Website": "www.balnear-corporesano.ro",
#         "Autoritatea tutelara": "Complex Balnear si de Recuperare C.A.A. S.R.L.",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 10,
#         "Nume": "SPITAL CLINIC JUDETEAN DE URGENTA BRA?OV",
#         "Cod A.N.M.C.S.": "A010",
#         "Judet": "Brasov",
#         "Clasificare": "II",
#         "TIP USP (in functie de specificul patologiei tratate)": "urgenta",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "clinic cu sectii universitare",
#         "Adresa completa a sediului principal": "Bd. Eroilor nr.5 cod 500007 Brasov, jud. Brasov",
#         "Adresa email oficiala": "sjbrasov@rdslink.ro",
#         "Website": "www.hospbv.ro",
#         "Autoritatea tutelara": "CONSILIUL JUDETEAN BRASOV",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 11,
#         "Nume": "SPITALUL DE RECUPERARE \"SF. GHEORGHE\" BOTOSANI",
#         "Cod A.N.M.C.S.": "A011",
#         "Judet": "Botosani",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Botosani,str. Piata Revolutiei, nr.1, cod 710236",
#         "Adresa email oficiala": "secretariat@spitalbt-sfgheorghe.ro",
#         "Website": "www.spitalbt-sfgheorghe.ro",
#         "Autoritatea tutelara": "Consiliul local al Municipiului Botosani",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 12,
#         "Nume": "SPITALUL DE PNEUMOFTIZIOLOGIE TUDOR VLADIMIRESCU",
#         "Cod A.N.M.C.S.": "A012",
#         "Judet": "Gorj",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Tg Jiu, Strada Victoriei, nr. 4, Gorj",
#         "Adresa email oficiala": "office.spitaltv@gmail.com",
#         "Website": "www.spitaltv.ro",
#         "Autoritatea tutelara": "Consiliul Judetean Gorj",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 13,
#         "Nume": "INSTITUTUL ONCOLOGIC \"PROF. DR. I. CHIRICUTA",
#         "Cod A.N.M.C.S.": "A013",
#         "Judet": "Cluj",
#         "Clasificare": "I M",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "institut",
#         "Adresa completa a sediului principal": "Strada Cristian Popi?teanu, nr. 1-3, sector 1, cod 010024, Bucure?ti",
#         "Adresa email oficiala": "office@iocn.ro",
#         "Website": "www.iocn.ro",
#         "Autoritatea tutelara": "Ministerul Sanatatii",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria III Acreditat cu rezerve",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 14,
#         "Nume": "SPITAL PSIHIATRIE NUCET",
#         "Cod A.N.M.C.S.": "A014",
#         "Judet": "Bihor",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "str. Parcul Traian, nr. 5, Oradea, Bihor",
#         "Adresa email oficiala": "spnucet@yahoo.com",
#         "Website": "www.spnucet.ro",
#         "Autoritatea tutelara": "Consiliul Judetean Bihor",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 15,
#         "Nume": "SPITALUL DE PEDIATRIE PITESTI",
#         "Cod A.N.M.C.S.": "A015",
#         "Judet": "Arges",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Pitesti, Piata Vasile Milea Nr. 1, Jud. Arges",
#         "Adresa email oficiala": "spital.pediatrie@adslexpress.ro",
#         "Website": "http://www.pediatriepitesti.ro/",
#         "Autoritatea tutelara": "Consiliul Judetean Arges",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria IV Acreditat cu incredere redusa",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 16,
#         "Nume": "SPITALUL SF SAVA S.R.L.",
#         "Cod A.N.M.C.S.": "A016",
#         "Judet": "Buzau",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "pentru bolnavi cu afectiuni cronice",
#         "TIP USP (in functie de regimul proprietatii)": "privat",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "BUZAU, STR. CRIZANTEMELOR, NR.5, JUD.BUZAU",
#         "Adresa email oficiala": "sfantulsava.buzau@gmail.com",
#         "Website": "http//www.spitalulsfsava.ro",
#         "Autoritatea tutelara": "SPITALUL SF.SAVA",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 17,
#         "Nume": "SPITALUL CLINIC DE PSIHIATRIE \ufffdPROF. DR. ALEXANDRU OBREGIA\ufffd",
#         "Cod A.N.M.C.S.": "A017",
#         "Judet": "Bucuresti",
#         "Clasificare": "I M",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "clinic cu sectii universitare",
#         "Adresa completa a sediului principal": "Str. Sf. Ecaterina, Nr. 3, Sect. 4, Bucure?ti",
#         "Adresa email oficiala": "secretariat@spital-obregia.ro",
#         "Website": "spital-obregia.ro",
#         "Autoritatea tutelara": "AdministraTia Spitalelor ?i Serviciilor Medicale Bucure?ti",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 18,
#         "Nume": "SPITALUL DE PSIHIATRIE TULGHES",
#         "Cod A.N.M.C.S.": "A018",
#         "Judet": "Harghita",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "M-Ciuc",
#         "Adresa email oficiala": "spitalultulghes@yahoo.com",
#         "Website": "www.psihiatrietulghes.ro",
#         "Autoritatea tutelara": "Consiliul Judetean Harghita",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria VI Neacreditat",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 19,
#         "Nume": "S.C. CENTRUL MEDICAL UNIREA SRL",
#         "Cod A.N.M.C.S.": "A019",
#         "Judet": "Bucuresti",
#         "Clasificare": "Neclasificat",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "privat",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "str. Guillaume Kroll nr. 5, L-1882 Luxembourg, Marele Ducat al Luxembourg",
#         "Adresa email oficiala": "office@reginamaria.ro",
#         "Website": "https://www.reginamaria.ro/spitale/spitalul-baneasa",
#         "Autoritatea tutelara": "Royal Capital Investments S.a.r.l., a o societate inregistrata conform legilor din Luxembourg",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 20,
#         "Nume": "SANATORIUL BALNEAR ?I DE RECUPERARE TECHIRGHIOL",
#         "Cod A.N.M.C.S.": "A020",
#         "Judet": "Constanta",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "pentru bolnavi cu afectiuni cronice",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Strada Cristian Popi?teanu, nr. 1-3, sector 1, cod 010024, Bucure?ti",
#         "Adresa email oficiala": "sbtghiol@sbtghiol.ro",
#         "Website": "http://www.sbtghiol.ro/",
#         "Autoritatea tutelara": "MINISTERUL SaNaTatII",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 21,
#         "Nume": "SPITALUL DR. CAIUS TIBERIU SPARCHEZ",
#         "Cod A.N.M.C.S.": "A021",
#         "Judet": "Brasov",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "str. MITROPILIT IOAN METIANU, nr. 1",
#         "Adresa email oficiala": "secretariat@spitalzarnesti.ro",
#         "Website": "www.spitalcts.ro",
#         "Autoritatea tutelara": "PRIMaRIA ORA? ZaRNE?TI",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 22,
#         "Nume": "SPITALUL DE BOLI CRONICE \"SF.LUCA",
#         "Cod A.N.M.C.S.": "A022",
#         "Judet": "Bucuresti",
#         "Clasificare": "II M",
#         "TIP USP (in functie de specificul patologiei tratate)": "pentru bolnavi cu afectiuni cronice",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "clinic cu sectii universitare",
#         "Adresa completa a sediului principal": "STR. SF ECATERINA , NR 3 , SECT 4 , BUCURESTI",
#         "Adresa email oficiala": "spitalul.sf.luca@gmail.com",
#         "Website": "http://website.spitalulsfluca.ro",
#         "Autoritatea tutelara": "ASSMB",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 23,
#         "Nume": "CENTRUL DE EVALUARE ?I TRATAMENT A TOXICODEPENDENTELOR PENTRU TINERI SF. STELIAN",
#         "Cod A.N.M.C.S.": "A023",
#         "Judet": "Bucuresti",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "STRADA SFANTA ECATERINA NR.3, SECTOR 4",
#         "Adresa email oficiala": "cettt_sf.stelian@yahoo.com",
#         "Website": "www.cetttsfantulstelian.ro",
#         "Autoritatea tutelara": "ADMINISTRATIA SPITALELOR SI SERVICIILOR MEDICALE BUCURESTI",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 24,
#         "Nume": "SPITAL MUNICIPAL BLAJ",
#         "Cod A.N.M.C.S.": "A024",
#         "Judet": "Alba",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Blaj, P-ta 1848, nr. 1, 515400, jud. Alba",
#         "Adresa email oficiala": "secretariat@spitalblaj.ro",
#         "Website": "www.spitalblaj.ro",
#         "Autoritatea tutelara": "UAT Municipiul Blaj",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 25,
#         "Nume": "SPITALUL SOVATA-NIRAJ",
#         "Cod A.N.M.C.S.": "A025",
#         "Judet": "Mures",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "SOVATA STR. PRINCIPALA NR 153",
#         "Adresa email oficiala": "csssovata@yahoo.com",
#         "Website": "www.spitalsovata.ro",
#         "Autoritatea tutelara": "CONSILIUL LOCAL SOVATA",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 26,
#         "Nume": "SPITALUL JUDETEAN DE URGENTA DR.FOGOLY\ufffdN KRIST\ufffdF",
#         "Cod A.N.M.C.S.": "A027",
#         "Judet": "Covasna",
#         "Clasificare": "III",
#         "TIP USP (in functie de specificul patologiei tratate)": "urgenta",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Str.Piata Libertatii Nr.4",
#         "Adresa email oficiala": "secretariat@administrativ.spitfog.ro",
#         "Website": "www.spitfog.ro",
#         "Autoritatea tutelara": "Consiliul Judetean Covasna",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 27,
#         "Nume": "SPITALUL DE BOLI PSIHICE CRONICE BORSA",
#         "Cod A.N.M.C.S.": "A029",
#         "Judet": "Cluj",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "pentru bolnavi cu afectiuni cronice",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "CALEA DOROBANTILOR,NR.106,CLUJ NAPOCA,CLUJ",
#         "Adresa email oficiala": "office@spitalpsihiatrieborsa.ro",
#         "Website": "www.spitalpsihiatrieborsa.ro",
#         "Autoritatea tutelara": "CONSILIUL JUDETEAN CLUJ",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 28,
#         "Nume": "SPITAL MUNICIPAL GHEORGHENI",
#         "Cod A.N.M.C.S.": "A030",
#         "Judet": "Harghita",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "PiaTa LibertaTii nr. 27. Jud. Harghita, Romania",
#         "Adresa email oficiala": "secretariat@spitalgh.ro",
#         "Website": "http://www.spitalgh.ro",
#         "Autoritatea tutelara": "MUNICIPIUL GHEORGHENI",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 29,
#         "Nume": "SPITALUL DE URGENTA AL MAI \ufffdPROF.DR.D.GEROTA\ufffd",
#         "Cod A.N.M.C.S.": "A031",
#         "Judet": "Bucuresti",
#         "Clasificare": "II",
#         "TIP USP (in functie de specificul patologiei tratate)": "urgenta",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Str. Mihai Voda nr. 17, sector 5",
#         "Adresa email oficiala": "spital.gerota@mai.gov.ro",
#         "Website": "http://www.spitalgerota.mai.gov.ro",
#         "Autoritatea tutelara": "Directia Medicala a Ministerului Afacerilor Interne",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 30,
#         "Nume": "SPITALUL MUNICIPAL DE URGENTA PASCANI",
#         "Cod A.N.M.C.S.": "A032",
#         "Judet": "Iasi",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "urgenta",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Str. Stefan cel Mare , nr.16 , Municipiul Pascani",
#         "Adresa email oficiala": "spitalulmunicipalpascani@yahoo.com",
#         "Website": "www.spitalulmunicipalpascani.ro",
#         "Autoritatea tutelara": "Unitatea Administrativ Teritoriala Pascani",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 31,
#         "Nume": "SPITALUL DE PSIHIATRIE VOILA",
#         "Cod A.N.M.C.S.": "A034",
#         "Judet": "Prahova",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Bulevardul Culturii, nr. 18 Campina, Prahova",
#         "Adresa email oficiala": "spitalpsihiatrie@gmail.com",
#         "Website": "www.spitalulvoila.ro",
#         "Autoritatea tutelara": "CONSILIUL LOCAL AL MUNICIPIULUI CaMPINA",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 32,
#         "Nume": "SPITALUL MUNICIPAL DR. AUREL TULBURE FAGARAS",
#         "Cod A.N.M.C.S.": "A035",
#         "Judet": "Brasov",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "LOC. FAGARAS,STR.Republicii nr 3, JUD.BRASOV",
#         "Adresa email oficiala": "secretariat@spitalulfagaras.ro",
#         "Website": "www.spitalulfagaras.ro",
#         "Autoritatea tutelara": "PRIMARIA MUNICIPIULUI FAGARAS",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria VI Neacreditat",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 33,
#         "Nume": "SPITALUL MUNICIPAL GHERLA",
#         "Cod A.N.M.C.S.": "A037",
#         "Judet": "Cluj",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "GHERLA, STR.BOBALNA NR.2",
#         "Adresa email oficiala": "secretariat@spitalgherla.ro",
#         "Website": "www.spitalgherla.ro",
#         "Autoritatea tutelara": "PRIMARIA MUNICIPIULUI GHERLA",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria V Decizie de prelungire a procesului de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 34,
#         "Nume": "SPITALUL ,,PROF.DR.EDUARD APETREI'' BUHUSI",
#         "Cod A.N.M.C.S.": "A038",
#         "Judet": "Bacau",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Str. Republicii, Nr.5 Buhu?i 605100 Bacau",
#         "Adresa email oficiala": "spitalbuhusi@gmail.com",
#         "Website": "www.spitalbuhusi.ro",
#         "Autoritatea tutelara": "Consiliul Local Buhusi",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria IV Acreditat cu incredere redusa",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 35,
#         "Nume": "SPITALUL DE ORTOPEDIESI TRAUMATOLOGIE AZUGA",
#         "Cod A.N.M.C.S.": "A039",
#         "Judet": "Prahova",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "AZUGA, STR. INDEPENDENTEI, NR. 10A",
#         "Adresa email oficiala": "spitalazuga@yahoo.com",
#         "Website": "www.ortopedieazuga.ro",
#         "Autoritatea tutelara": "CONSILIUL LOCAL AZUGA",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 36,
#         "Nume": "SPITALUL DE PSIHIATRIE ?I PENTRU MASURI DE SIGURANTA SAPOCA",
#         "Cod A.N.M.C.S.": "A040",
#         "Judet": "Buzau",
#         "Clasificare": "III",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Str. Intr. Cristian Popisteanu, Nr 1-3",
#         "Adresa email oficiala": "secretariat@hsapoca.ro",
#         "Website": "www.hsapoca.ro",
#         "Autoritatea tutelara": "Ministerul Sanatatii",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 37,
#         "Nume": "CARDIO MED S.R.L. TARGU MURES",
#         "Cod A.N.M.C.S.": "A041",
#         "Judet": "Mures",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "privat",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "MUN. TIRGU MURES, STR. 22 DECEMBRIE 1989, NR. 76-78, JUD, MURES",
#         "Adresa email oficiala": "contact@cardiomedtgm.ro",
#         "Website": "https://www.cardiomedtgm.ro/",
#         "Autoritatea tutelara": "AGA",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria V Decizie de prelungire a procesului de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 38,
#         "Nume": "SPITAL - CENTRUL MEDICAL TOPMED",
#         "Cod A.N.M.C.S.": "A042",
#         "Judet": "Mures",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "privat",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "STR. DOROBANTILOR, NR. 1, TG.MURES",
#         "Adresa email oficiala": "office@topmed.ro",
#         "Website": "www.topmed.ro",
#         "Autoritatea tutelara": "SC CENTRUL MEDICAL TOPMED SRL",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 39,
#         "Nume": "SPITALUL DE PNEUMOFTIZIOLOGIE SATU MARE",
#         "Cod A.N.M.C.S.": "A043",
#         "Judet": "Satu Mare",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "SATU MARE,PIATA 25 OCTOMBRIE NR 1,COD POSTAL 440026",
#         "Adresa email oficiala": "tbc_sm@yahoo.com",
#         "Website": "www.spitalpnfsm.ro",
#         "Autoritatea tutelara": "CONSILIUL JUDETEAN SATU MARE",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 40,
#         "Nume": "SOCIETATEA MANITOU MED SRL CLINICA GYNOPRAX",
#         "Cod A.N.M.C.S.": "A044",
#         "Judet": "Satu Mare",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "privat",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "I.C.BRATIANU nr. 2/6 SATU MARE",
#         "Adresa email oficiala": "gynoprax.adm@gmail.com",
#         "Website": "www.gynoprax.ro",
#         "Autoritatea tutelara": "privat",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 41,
#         "Nume": "S.C. ECOMED S.R.L. VINTILA-VODA",
#         "Cod A.N.M.C.S.": "A045",
#         "Judet": "Buzau",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "pentru bolnavi cu afectiuni cronice",
#         "TIP USP (in functie de regimul proprietatii)": "privat",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "COMUNA VINTILA-VODA , STR. PRINCIPALA , NR.1 , JUDET BUZAU",
#         "Adresa email oficiala": "ecomedbz@yahoo.com",
#         "Website": "www.ecomedbz.ro",
#         "Autoritatea tutelara": "S.C. ECOMED S.R.L. VINTILA-VODA",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 42,
#         "Nume": "SPITALUL DE PSIHIATRIE \" ELISABETA DOAMNA\" GALATI",
#         "Cod A.N.M.C.S.": "A047",
#         "Judet": "Galati",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "clinic cu sectii universitare",
#         "Adresa completa a sediului principal": "STRADA TRAIAN NR. 97, BL.. A4, PARTER",
#         "Adresa email oficiala": "secretariat@spitalpsihiatrie-galati.ro",
#         "Website": "www.spitalpsihiatrie-galati.ro",
#         "Autoritatea tutelara": "CONSILIUL LOCAL GALATI - PRIMARIA GALATI - SERVICIUL DE ASISTENTA MEDICALA AL MUNICIPIULUI GALATI",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 43,
#         "Nume": "SPITALUL DE PSIHIATRIE",
#         "Cod A.N.M.C.S.": "A048",
#         "Judet": "Suceava",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "STR. 22 DECEMBRIE, NR. 2, CAMPULUNG MOLDOVENESC",
#         "Adresa email oficiala": "office@spcm.ro",
#         "Website": "www.spcm.ro",
#         "Autoritatea tutelara": "CONSILIUL LOCAL CAMPULUNG MOLDOVENESC",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria V Decizie de prelungire a procesului de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 44,
#         "Nume": "SPITALUL ORA?ENESC ZIMNICEA",
#         "Cod A.N.M.C.S.": "A049",
#         "Judet": "Teleorman",
#         "Clasificare": "IV",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "str Giurgiu, nr. 1 ,Zimnicea",
#         "Adresa email oficiala": "spitalzimnicea@yahoo.com",
#         "Website": "www.spital-zimnicea.ro",
#         "Autoritatea tutelara": "UAT ZIMNICEA",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria III Acreditat cu rezerve",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 45,
#         "Nume": "PENITENCIARUL SPITAL DEJ",
#         "Cod A.N.M.C.S.": "A050",
#         "Judet": "Cluj",
#         "Clasificare": "III",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "STR. MARIA GHICULEASA NR.47",
#         "Adresa email oficiala": "psdej@anp.gov.ro",
#         "Website": "http://anp.gov.ro/penitenciarul-spital-dej/",
#         "Autoritatea tutelara": "ANP",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 46,
#         "Nume": "SPITALUL MILITAR DE URGENTA \"DR. ARISTIDE SERFIOTI\" GALATI",
#         "Cod A.N.M.C.S.": "A051",
#         "Judet": "Galati",
#         "Clasificare": "III",
#         "TIP USP (in functie de specificul patologiei tratate)": "urgenta",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Bucuresti , str.Institutului Medico-Militar , nr.3-5, Sector 1",
#         "Adresa email oficiala": "secretariat@smugalati.ro",
#         "Website": "www.smugalati.ro",
#         "Autoritatea tutelara": "Directia Medicala a MINISTERULUI APARARII NATIONALE",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 47,
#         "Nume": "SPITALUL CLINIC DE RECUPERARE IASI",
#         "Cod A.N.M.C.S.": "A052",
#         "Judet": "Iasi",
#         "Clasificare": "I M",
#         "TIP USP (in functie de specificul patologiei tratate)": "pentru bolnavi cu afectiuni cronice",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "clinic cu sectii universitare",
#         "Adresa completa a sediului principal": "stefan cel mare 11",
#         "Adresa email oficiala": "secretariat@scr.ro",
#         "Website": "www.scr.ro",
#         "Autoritatea tutelara": "Consiliul Local al Municipiului Iasi",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 48,
#         "Nume": "SC CMC PRAXIS SRL",
#         "Cod A.N.M.C.S.": "A054",
#         "Judet": "Alba",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "general",
#         "TIP USP (in functie de regimul proprietatii)": "privat",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "STR. TULNICULUI, NR. 24, LOC. ALBA IULIA, JUD. ALBA",
#         "Adresa email oficiala": "cmcpraxis@gmail.com",
#         "Website": "www.doctorcibu.ro",
#         "Autoritatea tutelara": "CMC PRAXIS SRL",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 49,
#         "Nume": "SPITALUL CLINIC DE PSIHIATRIE SI NEUROLOGIE BRASOV",
#         "Cod A.N.M.C.S.": "A055",
#         "Judet": "Brasov",
#         "Clasificare": "II M",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "clinic cu sectii universitare",
#         "Adresa completa a sediului principal": "B-dul Eroilor nr. 5",
#         "Adresa email oficiala": "relatiicupublicul@spnbrasov.ro",
#         "Website": "www.spnbrasov.ro",
#         "Autoritatea tutelara": "Consiliul Judetean Brasov",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria IV Acreditat cu incredere redusa",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 50,
#         "Nume": "SANATORIUL BALNEAR ?I DE RECUPERARE MANGALIA",
#         "Cod A.N.M.C.S.": "A056",
#         "Judet": "Constanta",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "pentru bolnavi cu afectiuni cronice",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "Strada Cristian Popi?teanu, nr. 1-3, sector 1, cod 010024, Bucure?ti",
#         "Adresa email oficiala": "office@balnear.net",
#         "Website": "www.balnear.net",
#         "Autoritatea tutelara": "Ministerul Sanatatii",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria III Acreditat cu rezerve",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 51,
#         "Nume": "SPITALUL CLINIC DE NEUROPSIHIATRIE CRAIOVA",
#         "Cod A.N.M.C.S.": "A057",
#         "Judet": "Dolj",
#         "Clasificare": "II M",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "clinic cu sectii universitare",
#         "Adresa completa a sediului principal": "STR. A. I CUZA, NR.7",
#         "Adresa email oficiala": "contact@scnpc.ro",
#         "Website": "www.scnpc.ro",
#         "Autoritatea tutelara": "PRIMARIA MUNICIPIULUI CRAIOVA - CONSILIUL LOCAL AL MUNICIPIULUI CRAIOVA",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 52,
#         "Nume": "SPITALUL PRIVAT S.C. BETHESDA S.R.L.",
#         "Cod A.N.M.C.S.": "A058",
#         "Judet": "Suceava",
#         "Clasificare": "V",
#         "TIP USP (in functie de specificul patologiei tratate)": "specialitate",
#         "TIP USP (in functie de regimul proprietatii)": "privat",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "STR. TRAIAN,NR. 5, Calafat, cod 205200, Dolj",
#         "Adresa email oficiala": "cosmin@bethesda.ro",
#         "Website": "www.bethesda.ro",
#         "Autoritatea tutelara": "privat",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Categoria II Acreditat cu recomandari",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 53,
#         "Nume": "SPITALUL CLINIC DE URGENTA \ufffdPROF.DR. AGRIPPA IONESCU\ufffd",
#         "Cod A.N.M.C.S.": "A059",
#         "Judet": "Bucuresti",
#         "Clasificare": "II",
#         "TIP USP (in functie de specificul patologiei tratate)": "urgenta",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "clinic cu sectii universitare",
#         "Adresa completa a sediului principal": "B-dul Libertatii nr. 14",
#         "Adresa email oficiala": "agrippa@dcti.ro",
#         "Website": "www.spitalulagrippaionescu.ro",
#         "Autoritatea tutelara": "Serviciul Roman de Informatii",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": 54,
#         "Nume": "SPITAL MUNICIPAL DE URGENTA \"ELENA BELDIMAN\" BARLAD",
#         "Cod A.N.M.C.S.": "A060",
#         "Judet": "Vaslui",
#         "Clasificare": "III",
#         "TIP USP (in functie de specificul patologiei tratate)": "urgenta",
#         "TIP USP (in functie de regimul proprietatii)": "public",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "fara invatamant",
#         "Adresa completa a sediului principal": "str. 1 Decembrie 1918 nr.21, Barlad",
#         "Adresa email oficiala": "spitalul.municipal.barlad@gmail.com",
#         "Website": "www.spital-barlad.ro",
#         "Autoritatea tutelara": "CONSILIUL LOCAL MUNICIPAL BARLAD",
#         "Acreditare ciclul I": "Acreditat",
#         "Acreditare ciclul II": "Unitate aflata in proces de acreditare",
# ...
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     },
#     {
#         "Nr. Crt.": "",
#         "Nume": "",
#         "Cod A.N.M.C.S.": "",
#         "Judet": "",
#         "Clasificare": "",
#         "TIP USP (in functie de specificul patologiei tratate)": "",
#         "TIP USP (in functie de regimul proprietatii)": "",
#         "TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)": "",
#         "Adresa completa a sediului principal": "",
#         "Adresa email oficiala": "",
#         "Website": "",
#         "Autoritatea tutelara": "",
#         "Acreditare ciclul I": "",
#         "Acreditare ciclul II": "",
#         "": "",
#         "__1": "",
#         "__2": ""
#     }
# ]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Laptop 20\Desktop\ghibs\bootcamp\2022\python_workshop\notebooks\10_test.ipynb Cell 11 in <cell line: 11>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Laptop%2020/Desktop/ghibs/bootcamp/2022/python_workshop/notebooks/10_test.ipynb#ch0000010?line=7'>8</a> parsed = json.loads(hospitals)
#       <a href='vscode-notebook-cell:/c%3A/Users/Laptop%2020/Desktop/ghibs/bootcamp/2022/python_workshop/notebooks/10_test.ipynb#ch0000010?line=8'>9</a> print(json.dumps(parsed, indent=4))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Laptop%2020/Desktop/ghibs/bootcamp/2022/python_workshop/notebooks/10_test.ipynb#ch0000010?line=10'>11</a> print(hospitals.head())
#
# AttributeError: 'str' object has no attribute 'head'

# %% [markdown]
# How many rows are in this dataset?

# %%
print(hospitals.shape)
print(hospitals.shape[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Laptop 20\Desktop\ghibs\bootcamp\2022\python_workshop\notebooks\10_test.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Laptop%2020/Desktop/ghibs/bootcamp/2022/python_workshop/notebooks/10_test.ipynb#ch0000012?line=0'>1</a> print(hospitals.shape)
#       <a href='vscode-notebook-cell:/c%3A/Users/Laptop%2020/Desktop/ghibs/bootcamp/2022/python_workshop/notebooks/10_test.ipynb#ch0000012?line=1'>2</a> print(hospitals.shape[0])
#
# AttributeError: 'str' object has no attribute 'shape'

# %% [markdown]
# What are the columns in this dataset?

# %%
print(hospitals.columns)
print(hospitals.dtypes)
# Out:
# Index([], dtype='object')
# Series([], dtype: object)

# %% [markdown]
# Drop the unnecessary columns:
# * Nr. Crt.
# * TIP USP (din punct de vedere al invatamantului si al cercetarii stiintifice medicale)
# * the last three columns

# %%
hospitals.drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Laptop 20\Desktop\ghibs\bootcamp\2022\python_workshop\notebooks\10_test.ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Laptop%2020/Desktop/ghibs/bootcamp/2022/python_workshop/notebooks/10_test.ipynb#ch0000016?line=0'>1</a> hospitals.drop()
#
# File c:\programs\miniconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\programs\miniconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File c:\programs\miniconda3\lib\site-packages\pandas\core\generic.py:4259, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4257     axes, _ = self._construct_axes_from_arguments((index, columns), {})
#    4258 else:
# -> 4259     raise ValueError(
#    4260         "Need to specify at least one of 'labels', 'index' or 'columns'"
#    4261     )
#    4263 obj = self
#    4265 for axis, labels in axes.items():
#
# ValueError: Need to specify at least one of 'labels', 'index' or 'columns'

# %% [markdown]
# Apply the following transformations to the columns, so that they are easier to work with:
# * lowercase all columns
# * `TIP USP (in functie de specificul patologiei tratate)` rename to `tip_patologie`
# * `TIP USP (in functie de regimul proprietatii)` rename to `tip`
# * `Adresa completa a sediului principal` rename to `adresa`
# * `Adresa email oficiala` rename to `email`
# * `Autoritatea tutelara` rename to `autoritate_tutelara`
# * `Acreditare ciclul I` rename to `acreditare_i`
# * `Acreditare ciclul II` rename to `acreditare_ii`

# %%
#lowercase all columns
hospitals = hospitals.rename(columns=lambda x: x.lower())
hospitals.head()
#rename
hospitals.rename(
    columns={
        "TIP USP" : "tip"
        "Adresa completa a sediului principal" : "adresa"
        "Adresa email oficiala" : "email"
        "Autoritatea tutelara" : "autoritate_tutelara"
        "Acreditare ciclul I" : "acreditare_i"
        "Acreditare ciclul II" : "acreditare_ii"

    },
    inplace=True
)
hospitals.columns
# Out:
#   Input In [48]
#     "Adresa completa a sediului principal" : "adresa"
#                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# The total number of hospitals in this dataset is 762, however the actual number of rows is greater than that.
#
# Identify and remove the empty (blank space) rows.

# %% [markdown]
# How many public hospitals and how many private hospitals are in this dataset?

# %% [markdown]
# Inspect the values in the `acreditare_i` column + print them.

# %%
hospitals[['acreditare_i']].shape()

# %% [markdown]
# Create a dataframe containing the hospitals that are *not* accredited.

# %% [markdown]
# How many hospitals are *not* accredited?

# %% [markdown]
# Pick a county (judet) for a more in-depth analysis.
# (Bucuresti is also a county)

# %%
judet = ...

# %% [markdown]
# According to this dataset, how many hospitals are in this county?

# %% [markdown]
# For the chosen county, create a Dataframe that contains the following information:
# * judet
# * tip (public, privat)
# * count of unaccredited hospitals
# * count of accredited hospitals

# %%
stat = ...
stat.head()

# %% [markdown]
# Create a plot that highlights
# * the number of accredited public hospitals
# * the number of accredited private hospitals
# * the number of unaccredited public hospitals
# * the number of unaccredited private hospitals
#
# The expected output for Bucuresti can be found  [here](/2022/python_workshop/notebooks/results/expected/output_test.png).

# %%
plot_acreditat = ...

# %%
plot_neacreditat = ...

# %%
plot_data = ...
plot_data.head()

# %%
plot_data.plot(kind="bar")
